# %%
import pandas as pd
from main import *
from io import StringIO
from data import *
from model import *
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 100)
import plotly.graph_objects as go
# %matplotlib inline

import plotly.io as pio
pio.renderers.default = 'notebook'  # or 'notebook_connected'
# Out:
# /Users/jlawson/Documents/LastManStanding/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
get_url("http://api.clubelo.com/Fixtures")
# Out:
# Getting from http://api.clubelo.com/Fixtures
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_url("http://api.clubelo.com/Fixtures")
#
# File ~/Documents/LastManStanding/data.py:119, in mutable_lru_cache.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     117 hashable_args = tuple(make_hashable(arg) for arg in args)
#     118 hashable_kwargs = {k: make_hashable(v) for k, v in kwargs.items()}
# --> 119 return in_memory_cache(*hashable_args, **hashable_kwargs)
#
# File ~/Documents/LastManStanding/data.py:95, in mutable_lru_cache.<locals>.decorator.<locals>.disk_dispatch(*hashable_args, **hashable_kwargs)
#      92 if cached is not None:
#      93     return _CachedResponse(cached)
# ---> 95 result = f(*hashable_args, **hashable_kwargs)
#      96 _write_cache_entry(cache_file, result)
#      97 return result
#
# File ~/Documents/LastManStanding/data.py:138, in get_url(url, params, headers)
#     136 print(f"Getting from {url}")
#     137 response = requests.get(url, params=params, headers=headers)
# --> 138 response.raise_for_status()
#     140 print(f"Got response 200 from {url}, with headers:")
#     141 print(response.headers)
#
# File ~/Documents/LastManStanding/venv/lib/python3.9/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 502 Server Error: Bad Gateway for url: http://api.clubelo.com/Fixtures

# %%
f"http://api.clubelo.com/{date.strftime('%Y-%m-%d')}"

# %%
tournament = Tournament.from_apis()

# %%
df = pd.concat([pd.DataFrame(x) for x in tournament.matches.values()])

df['dateTime'] = pd.to_datetime(df['date_id'].astype(str))
df['weekday'] = df['dateTime'].dt.weekday
df['week_of_year'] = df['dateTime'].apply(lambda date: date.isocalendar().week)

# anchor_weekday = 5
# df['my_week'] = df['dateTime'].apply(lambda d: d - pd.Timedelta(days=(d.weekday() + 3) % 7))
# df['my_weekday'] = df['my_week'].dt.weekday

# %%
plt.figure(figsize=(15, 7))
for team in ['Liverpool', 'Sheffield United']:
    subset = df[(df['home_team'] == team) | (df['away_team'] == team)]
    plt.step(subset['dateTime'], subset['week_number'])
